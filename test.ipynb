# %%
import networkx as nx

fuck_it = nx.DiGraph()
fuck_it.add_edge('1','2', weight = 10)
fuck_it.add_edge('1','5', weight = 5)
fuck_it.add_edge('1','3', weight = 8)
fuck_it.add_edge('3','5', weight = 11)
fuck_it.add_edge('2','5', weight = 8)
fuck_it.add_edge('2','4', weight = 10)
fuck_it.add_edge('5','4', weight = 4)
fuck_it.add_edge('5','7', weight = 8)
fuck_it.add_edge('3','7', weight = 10)
fuck_it.add_edge('3','8', weight = 8)
fuck_it.add_edge('7','8', weight = 2)
fuck_it.add_edge('8','9', weight = 2)
fuck_it.add_edge('5','9', weight = 7)
fuck_it.add_edge('5','6', weight = 8)
fuck_it.add_edge('4','6', weight = 6)
fuck_it.add_edge('6','9', weight = 9)
nx.draw_networkx(fuck_it)

# %%
nx.shortest_path(fuck_it, '1', '9')
# Out:
# ['1', '5', '9']

# %%
nx.dag_longest_path(fuck_it, weight='weight')
# Out:
# ['1', '3', '5', '4', '6', '9']
